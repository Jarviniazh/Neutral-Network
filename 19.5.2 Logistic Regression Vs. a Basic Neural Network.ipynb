# %% [markdown]
# # 19.5.2 Logistic Regression Vs. a Basic Neural Network

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('Resources/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome", axis=1)

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Logistic Regression

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs", max_iter=200, random_state=42)

# Train the model 
log_classifier.fit(X_train_scaled, y_train)

# Predict
y_pred = log_classifier.predict(X_test_scaled)

# Evaluate the model
print(f"Logistic Regression model accuracy: {accuracy_score(y_test, y_pred):.3f}")
# Out:
# Logistic Regression model accuracy: 0.734

# %% [markdown]
# ### Basic Neural Network Model

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, input_dim=8, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6121 - accuracy: 0.6979
# Epoch 2/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5876 - accuracy: 0.7066
# Epoch 3/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5683 - accuracy: 0.7118
# Epoch 4/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5525 - accuracy: 0.7274
# Epoch 5/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5392 - accuracy: 0.7378
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.7465
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5191 - accuracy: 0.7517
# Epoch 8/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5110 - accuracy: 0.7569
# Epoch 9/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5040 - accuracy: 0.7639
# Epoch 10/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4978 - accuracy: 0.7726
# Epoch 11/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4927 - accuracy: 0.7726
# Epoch 12/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.7743
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4834 - accuracy: 0.7760
# Epoch 14/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4795 - accuracy: 0.7812
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.7812
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4727 - accuracy: 0.7830
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.7847
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4673 - accuracy: 0.7865
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7865
# Epoch 20/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4627 - accuracy: 0.7882
# Epoch 21/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4607 - accuracy: 0.7865
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.7882
# Epoch 23/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4570 - accuracy: 0.7847
# Epoch 24/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4554 - accuracy: 0.7847
# Epoch 25/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4538 - accuracy: 0.7882
# Epoch 26/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7865
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.7847
# Epoch 28/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4499 - accuracy: 0.7899
# Epoch 29/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4488 - accuracy: 0.7882
# Epoch 30/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4477 - accuracy: 0.7917
# Epoch 31/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4469 - accuracy: 0.7917
# Epoch 32/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4461 - accuracy: 0.7899
# Epoch 33/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.7917
# Epoch 34/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4439 - accuracy: 0.7917
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.7899
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.7899
# Epoch 37/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.7917
# Epoch 38/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4408 - accuracy: 0.7917
# Epoch 39/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.7899
# Epoch 40/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4396 - accuracy: 0.7917
# Epoch 41/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4387 - accuracy: 0.7899
# Epoch 42/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.7899
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4378 - accuracy: 0.7882
# Epoch 44/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4366 - accuracy: 0.7899
# Epoch 45/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4360 - accuracy: 0.7934
# Epoch 46/100
# 18/18 [==============================] - 0s 999us/step - loss: 0.4355 - accuracy: 0.7934
# Epoch 47/100
# 18/18 [==============================] - 0s 997us/step - loss: 0.4346 - accuracy: 0.7934
# Epoch 48/100
# 18/18 [==============================] - 0s 997us/step - loss: 0.4341 - accuracy: 0.7934
# Epoch 49/100
# 18/18 [==============================] - 0s 999us/step - loss: 0.4337 - accuracy: 0.7934
# Epoch 50/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4331 - accuracy: 0.7951
# Epoch 51/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.7951
# Epoch 52/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4321 - accuracy: 0.7951
# Epoch 53/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.7951
# Epoch 54/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4310 - accuracy: 0.7969
# Epoch 55/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4306 - accuracy: 0.7969
# Epoch 56/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4302 - accuracy: 0.7969
# Epoch 57/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4299 - accuracy: 0.7986
# Epoch 58/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4299 - accuracy: 0.7986
# Epoch 59/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4288 - accuracy: 0.7986
# Epoch 60/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4281 - accuracy: 0.7969
# Epoch 61/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4279 - accuracy: 0.7969
# Epoch 62/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4276 - accuracy: 0.8003
# Epoch 63/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4271 - accuracy: 0.7986
# Epoch 64/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4266 - accuracy: 0.7986
# Epoch 65/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4261 - accuracy: 0.8003
# Epoch 66/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4256 - accuracy: 0.7986
# Epoch 67/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4251 - accuracy: 0.8003
# Epoch 68/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4246 - accuracy: 0.8003
# Epoch 69/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4242 - accuracy: 0.8003
# Epoch 70/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4241 - accuracy: 0.8021
# Epoch 71/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4236 - accuracy: 0.8056
# Epoch 72/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4232 - accuracy: 0.8038
# Epoch 73/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4227 - accuracy: 0.8021
# Epoch 74/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8038
# Epoch 75/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8038
# Epoch 76/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4216 - accuracy: 0.8038
# Epoch 77/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.8003
# Epoch 78/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4205 - accuracy: 0.8021
# Epoch 79/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4203 - accuracy: 0.8056
# Epoch 80/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8056
# Epoch 81/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4196 - accuracy: 0.8038
# Epoch 82/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.8021
# Epoch 83/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4187 - accuracy: 0.8021
# Epoch 84/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4181 - accuracy: 0.8021
# Epoch 85/100
# 18/18 [==============================] - 0s 998us/step - loss: 0.4178 - accuracy: 0.8003
# Epoch 86/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4176 - accuracy: 0.7986
# Epoch 87/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4171 - accuracy: 0.7986
# Epoch 88/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4168 - accuracy: 0.8003
# Epoch 89/100
# 18/18 [==============================] - 0s 997us/step - loss: 0.4166 - accuracy: 0.8003
# Epoch 90/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4158 - accuracy: 0.8038
# Epoch 91/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4159 - accuracy: 0.8003
# Epoch 92/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8003
# Epoch 93/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4151 - accuracy: 0.8038
# Epoch 94/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4146 - accuracy: 0.8021
# Epoch 95/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4146 - accuracy: 0.8056
# Epoch 96/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4141 - accuracy: 0.8021
# Epoch 97/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4137 - accuracy: 0.8021
# Epoch 98/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4138 - accuracy: 0.8021
# Epoch 99/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4131 - accuracy: 0.8021
# Epoch 100/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4129 - accuracy: 0.8021
# 6/6 - 0s - loss: 0.4811 - accuracy: 0.7344 - 137ms/epoch - 23ms/step
# Loss: 0.4811294376850128, Accuracy: 0.734375
